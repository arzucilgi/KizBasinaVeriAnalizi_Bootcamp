# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-df720f8d-12d4-4ffe-913b-f049d14b4137" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df720f8d-12d4-4ffe-913b-f049d14b4137">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
titanic=pd.read_csv("Titanic_dataset.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **1.	Kazada ölenlerin yaş ortalamasını bulunuz**

# %%
titanic[titanic["Survived"]==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         0       1
# 2              3         0       3
# 3              4         0       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         0       1
# 888          889         0       3
# 889          890         0       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic["Survived"]==0]["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# **2.	Kazada ölenlerin bilet fiyatlarının ortalamasını ve medyanını bulunuz**

# %%
titanic.loc[titanic["Survived"]==0,["Survived","Fare"]]
# Out:
#      Survived     Fare
# 0           0   7.2500
# 1           0  71.2833
# 2           0   7.9250
# 3           0  53.1000
# 4           0   8.0500
# ..        ...      ...
# 886         0  13.0000
# 887         0  30.0000
# 888         0  23.4500
# 889         0  30.0000
# 890         0   7.7500
#
# [891 rows x 2 columns]

# %%
titanic.loc[titanic["Survived"]==0,["Survived","Fare"]]["Fare"].mean()
# Out:
# np.float64(32.204207968574636)

# %%
titanic.loc[titanic["Survived"]==0]["Fare"].median()
# Out:
# 14.4542

# %% [markdown]
# **3.	Kazada ölen erkeklerin yaş ortalamasını bulunuz**

# %%
titanic.loc[(titanic["Survived"]==0) & (titanic["Sex"]=='male'),["Survived","Sex"]]
# Out:
#      Survived   Sex
# 0           0  male
# 4           0  male
# 5           0  male
# 6           0  male
# 7           0  male
# ..        ...   ...
# 881         0  male
# 883         0  male
# 884         0  male
# 886         0  male
# 890         0  male
#
# [468 rows x 2 columns]

# %%
titanic.loc[(titanic["Survived"]==0)&(titanic["Sex"]=='male'),["Survived","Sex","Age"]]["Age"].mean()
#Burda loc kullandığım için artık Age sütununu da yazdırdığım sütunlar arasına koymam lazım ki Age sütununun ortalamasını alabileyim
# Out:
# np.float64(30.72664459161148)

# %%
titanic.loc[(titanic["Survived"]==0)&(titanic["Sex"]=='male'),"Age"].mean()
# Out:
# np.float64(30.72664459161148)

# %% [markdown]
# **4.	Kazada ölen Kadınların yaş ortalamasını bulunuz**

# %%
titanic.loc[(titanic["Survived"]==0)&(titanic["Sex"]=='female'),["Survived","Sex","Age"]]["Age"].mean()
# Out:
# np.float64(27.915708812260537)

# %%
titanic.loc[(titanic["Survived"]==0)&(titanic["Sex"]=='female'),"Age"].mean()
# Out:
# np.float64(27.915708812260537)

# %%
titanic["Survived"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    0
# 889    0
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# **5.	Kazadan kurtulanların yaş ortalamasını bulunuz**

# %%
titanic.loc[titanic["Survived"]==1 , "Age"].mean()
# Out:
# np.float64(28.343689655172415)

# %% [markdown]
# **6.	Kazadan kurtulanların bilet fiyatlarının ortalamasını bulunuz**

# %%
titanic.loc[titanic["Survived"]==1,["Survived","Fare"]]
# Out:
#      Survived     Fare
# 1           1  71.2833
# 2           1   7.9250
# 3           1  53.1000
# 8           1  11.1333
# 9           1  30.0708
# ..        ...      ...
# 875         1   7.2250
# 879         1  83.1583
# 880         1  26.0000
# 887         1  30.0000
# 889         1  30.0000
#
# [342 rows x 2 columns]

# %%
titanic.loc[titanic["Survived"]==1,["Survived","Fare"]]["Fare"].mean()
# Out:
# np.float64(48.39540760233918)

# %% [markdown]
# **7.	Kazadan kurtulan toplam kişi sayısını bulunuz**

# %%
titanic[titanic["Survived"]==1]["Survived"].sum()
# Out:
# np.int64(342)

# %%
len(titanic[titanic["Survived"]==1])
# Out:
# 342

# %% [markdown]
# **8.	10 yaşından küçüklerin bilet fiyatlarının medyan değerini bulunuz**

# %%
titanic[titanic["Age"]<10]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
titanic.loc[titanic["Age"]<10,["Age","Fare"]]["Fare"].median()
# Out:
# 27.0

# %%
titanic.loc[titanic["Age"]<10,"Fare"].median()
# Out:
# 27.0

# %% [markdown]
# ***9.	1.sınıf, 2.sınıf ve 3.sınıf bilet fiyatlarının ortalama ve medyanlarını karşılaştırınız. ***

# %%
titanic.groupby("Pclass")["Fare"].median()
# Out:
# Pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: Fare, dtype: float64

# %%
titanic.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# **10.	Kazada ölen kadınların oranı ile erkeklerin oranını karşılaştırınız. (Örnek: erkekler için; ölen erkeklerin, erkek sayısına bölümü bu oranı vermektedir.)**

# %%
len(titanic.loc[(titanic["Survived"]==0)&(titanic["Sex"]=='female')])
# Out:
# 81

# %%
len(titanic.loc[(titanic['Survived']==0)&(titanic['Sex']=='male')])
# Out:
# 468

# %%
len(titanic.loc[(titanic['Survived']==0)&(titanic['Sex']=='male')])/len(titanic['Sex']=='male')
# Out:
# 0.5252525252525253

# %%
len(titanic.loc[(titanic['Survived']==0)&(titanic['Sex']=='female')])/len(titanic['Sex']=='female')
# Out:
# 0.09090909090909091
